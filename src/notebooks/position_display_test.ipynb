# %%
import pandas as pd
import os
import random
import matplotlib.pyplot as plt
from src.formation_gui.field import Field

# %%
# Load datasets
data_files_basepath = f"{os.getcwd()}\\resources"

plays = pd.read_csv(f"{data_files_basepath}\\reduced_data.csv")

# %%
rand_game = random.choice(plays.gameId.unique())
rand_play = random.choice(plays[plays['gameId'] == rand_game].playId.unique())

play = plays[(plays['gameId'] == rand_game) & (plays['playId'] == rand_play)]
play
# Out:
#        Unnamed: 0      gameId  playId    nflId playDirection       x      y  \
# 78653      159026  2022100201    2663  41232.0         right   99.38  26.35
# 78654      159027  2022100201    2663  42345.0         right   95.75  23.55
# 78655      159030  2022100201    2663  45550.0         right   99.58  24.94
# 78656      159032  2022100201    2663  46992.0         right   99.50  43.38
# 78657      159033  2022100201    2663  47797.0         right   99.91  22.17
# 78658      159034  2022100201    2663  47814.0         right   99.64  20.47
# 78659      159036  2022100201    2663  48374.0         right   99.21  33.78
# 78660      159037  2022100201    2663  48723.0         right   98.82  28.26
# 78661      159043  2022100201    2663  53543.0         right  100.16  23.57
# 78662      159045  2022100201    2663  54042.0         right   92.61  23.55
# 78663      159046  2022100201    2663  54473.0         right   99.76  10.26
#
#             o position offenseFormation
# 78653   87.17        T           PISTOL
# 78654  116.05       QB           PISTOL
# 78655   70.37        G           PISTOL
# 78656  108.98       WR           PISTOL
# 78657   70.11        G           PISTOL
# 78658   79.28        T           PISTOL
# 78659   85.40       WR           PISTOL
# 78660   94.39       TE           PISTOL
# 78661  116.64        C           PISTOL
# 78662   94.27       RB           PISTOL
# 78663   74.80       WR           PISTOL

# %%
from src.formation_gui.field import Field

field_viz = Field()

field_viz.generate_field()
field_viz.add_players(play)

# %%
if play.playDirection.unique()[0] == 'left':
    play = field_viz.flip_formation(play)

fig = field_viz.zoomed_formation(play)
