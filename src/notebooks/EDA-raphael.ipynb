# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load datasets
plays = pd.read_csv('plays.csv')
players = pd.read_csv('players.csv')

# Combine all tracking weeks into a single DataFrame (first 2 weeks)
tracking_files = [f'tracking_week_{i}.csv' for i in range(1, 2)]
tracking_list = []
for file in tracking_files:
    try:
        df = pd.read_csv(file, on_bad_lines='skip', engine='python')
        tracking_list.append(df)
    except Exception as e:
        print(f"Error reading {file}: {e}")
tracking = pd.concat(tracking_list, ignore_index=True)

# %%
# Display first few rows
print("Plays dataset:")
print(plays.head(), "\n")

print("Players dataset:")
print(players.head(), "\n")

print("Tracking dataset:")
print(tracking.head(), "\n")

# Display summary information
print(plays.info(), "\n")
print(players.info(), "\n")
print(tracking.info(), "\n")
# Out:
# Plays dataset:
#        gameId  playId                                    playDescription  \
# 0  2022102302    2655  (1:54) (Shotgun) J.Burrow pass short middle to...
# 1  2022091809    3698  (2:13) (Shotgun) J.Burrow pass short right to ...
# 2  2022103004    3146  (2:00) (Shotgun) D.Mills pass short right to D...
# 3  2022110610     348  (9:28) (Shotgun) P.Mahomes pass short left to ...
# 4  2022102700    2799  (2:16) (Shotgun) L.Jackson up the middle to TB...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        3     1         10            CIN           ATL          CIN
# 1        4     1         10            CIN           DAL          CIN
# 2        4     3         12            HOU           TEN          HOU
# 3        1     2         10             KC           TEN          TEN
# 4        3     2          8            BAL            TB           TB
#
#    yardlineNumber  ... yardsGained  homeTeamWinProbabilityAdded  \
# 0              21  ...           9                     0.004634
# 1               8  ...           4                     0.002847
# 2              20  ...           6                     0.000205
# 3              23  ...           4                    -0.001308
# 4              27  ...          -1                     0.027141
#
#    visitorTeamWinProbilityAdded expectedPointsAdded  isDropback  \
# 0                     -0.004634            0.702717        True
# 1                     -0.002847           -0.240509        True
# 2                     -0.000205           -0.218480        True
# 3                      0.001308           -0.427749        True
# 4                     -0.027141           -0.638912       False
#
#    pff_runConceptPrimary  pff_runConceptSecondary  pff_runPassOption  \
# 0                    NaN                      NaN                  0
# 1                    NaN                      NaN                  0
# 2                    NaN                      NaN                  0
# 3                    NaN                      NaN                  0
# 4                    MAN              READ OPTION                  0
#
#   pff_passCoverage pff_manZone
# 0          Cover-3        Zone
# 1         Quarters        Zone
# 2         Quarters        Zone
# 3         Quarters        Zone
# 4          Cover-1         Man
#
# [5 rows x 50 columns]
#
# Players dataset:
#    nflId height  weight   birthDate     collegeName position     displayName
# 0  25511    6-4     225  1977-08-03        Michigan       QB       Tom Brady
# 1  29550    6-4     328  1982-01-22        Arkansas        T    Jason Peters
# 2  29851    6-2     225  1983-12-02      California       QB   Aaron Rodgers
# 3  30842    6-6     267  1984-05-19            UCLA       TE  Marcedes Lewis
# 4  33084    6-4     217  1985-05-17  Boston College       QB       Matt Ryan
#
# Tracking dataset:
#        gameId  playId    nflId     displayName  frameId    frameType  \
# 0  2022091200      64  35459.0  Kareem Jackson        1  BEFORE_SNAP
# 1  2022091200      64  35459.0  Kareem Jackson        2  BEFORE_SNAP
# 2  2022091200      64  35459.0  Kareem Jackson        3  BEFORE_SNAP
# 3  2022091200      64  35459.0  Kareem Jackson        4  BEFORE_SNAP
# 4  2022091200      64  35459.0  Kareem Jackson        5  BEFORE_SNAP
#
#                     time  jerseyNumber club playDirection      x      y     s  \
# 0  2022-09-13 00:16:03.5          22.0  DEN         right  51.06  28.55  0.72
# 1  2022-09-13 00:16:03.6          22.0  DEN         right  51.13  28.57  0.71
# 2  2022-09-13 00:16:03.7          22.0  DEN         right  51.20  28.59  0.69
# 3  2022-09-13 00:16:03.8          22.0  DEN         right  51.26  28.62  0.67
# 4  2022-09-13 00:16:03.9          22.0  DEN         right  51.32  28.65  0.65
#
#       a   dis       o    dir                 event
# 0  0.37  0.07  246.17  68.34  huddle_break_offense
# 1  0.36  0.07  245.41  71.21                   NaN
# 2  0.23  0.07  244.45  69.90                   NaN
# 3  0.22  0.07  244.45  67.98                   NaN
# 4  0.34  0.07  245.74  62.83                   NaN
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16124 entries, 0 to 16123
# Data columns (total 50 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gameId                            16124 non-null  int64
#  1   playId                            16124 non-null  int64
#  2   playDescription                   16124 non-null  object
#  3   quarter                           16124 non-null  int64
#  4   down                              16124 non-null  int64
#  5   yardsToGo                         16124 non-null  int64
#  6   possessionTeam                    16124 non-null  object
#  7   defensiveTeam                     16124 non-null  object
#  8   yardlineSide                      15900 non-null  object
#  9   yardlineNumber                    16124 non-null  int64
#  10  gameClock                         16124 non-null  object
#  11  preSnapHomeScore                  16124 non-null  int64
#  12  preSnapVisitorScore               16124 non-null  int64
#  13  playNullifiedByPenalty            16124 non-null  object
#  14  absoluteYardlineNumber            16124 non-null  int64
#  15  preSnapHomeTeamWinProbability     16124 non-null  float64
#  16  preSnapVisitorTeamWinProbability  16124 non-null  float64
#  17  expectedPoints                    16124 non-null  float64
#  18  offenseFormation                  15936 non-null  object
#  19  receiverAlignment                 15936 non-null  object
#  20  playClockAtSnap                   16123 non-null  float64
#  21  passResult                        9736 non-null   object
#  22  passLength                        8726 non-null   float64
#  23  targetX                           8376 non-null   float64
#  24  targetY                           8376 non-null   float64
#  25  playAction                        16124 non-null  bool
#  26  dropbackType                      10321 non-null  object
#  27  dropbackDistance                  10158 non-null  float64
#  28  passLocationType                  9312 non-null   object
#  29  timeToThrow                       8705 non-null   float64
#  30  timeInTackleBox                   8917 non-null   float64
#  31  timeToSack                        608 non-null    float64
#  32  passTippedAtLine                  9336 non-null   object
#  33  unblockedPressure                 9755 non-null   object
#  34  qbSpike                           9336 non-null   object
#  35  qbKneel                           16124 non-null  int64
#  36  qbSneak                           6788 non-null   object
#  37  rushLocationType                  6788 non-null   object
#  38  penaltyYards                      384 non-null    float64
#  39  prePenaltyYardsGained             16124 non-null  int64
#  40  yardsGained                       16124 non-null  int64
#  41  homeTeamWinProbabilityAdded       16124 non-null  float64
#  42  visitorTeamWinProbilityAdded      16124 non-null  float64
#  43  expectedPointsAdded               16124 non-null  float64
#  44  isDropback                        16124 non-null  bool
#  45  pff_runConceptPrimary             9071 non-null   object
#  46  pff_runConceptSecondary           2821 non-null   object
#  47  pff_runPassOption                 16124 non-null  int64
#  48  pff_passCoverage                  15932 non-null  object
#  49  pff_manZone                       15932 non-null  object
# dtypes: bool(2), float64(15), int64(13), object(20)
# memory usage: 5.9+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1697 entries, 0 to 1696
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nflId        1697 non-null   int64
#  1   height       1697 non-null   object
#  2   weight       1697 non-null   int64
#  3   birthDate    1210 non-null   object
#  4   collegeName  1697 non-null   object
#  5   position     1697 non-null   object
#  6   displayName  1697 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 92.9+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2593997 entries, 0 to 2593996
# Data columns (total 18 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   gameId         int64
#  1   playId         int64
#  2   nflId          float64
#  3   displayName    object
#  4   frameId        int64
#  5   frameType      object
#  6   time           object
#  7   jerseyNumber   float64
#  8   club           object
#  9   playDirection  object
#  10  x              float64
#  11  y              float64
#  12  s              float64
#  13  a              float64
#  14  dis            float64
#  15  o              float64
#  16  dir            float64
#  17  event          object
# dtypes: float64(9), int64(3), object(6)
# memory usage: 356.2+ MB
# None

# %%
# Check for missing values
print("Missing values in Plays dataset:\n", plays.isnull().sum(), "\n")
print("Missing values in Players dataset:\n", players.isnull().sum(), "\n")
print("Missing values in Tracking dataset:\n", tracking.isnull().sum(), "\n")
# Out:
# Missing values in Plays dataset:
#  gameId                                  0
# playId                                  0
# playDescription                         0
# quarter                                 0
# down                                    0
# yardsToGo                               0
# possessionTeam                          0
# defensiveTeam                           0
# yardlineSide                          224
# yardlineNumber                          0
# gameClock                               0
# preSnapHomeScore                        0
# preSnapVisitorScore                     0
# playNullifiedByPenalty                  0
# absoluteYardlineNumber                  0
# preSnapHomeTeamWinProbability           0
# preSnapVisitorTeamWinProbability        0
# expectedPoints                          0
# offenseFormation                      188
# receiverAlignment                     188
# playClockAtSnap                         1
# passResult                           6388
# passLength                           7398
# targetX                              7748
# targetY                              7748
# playAction                              0
# dropbackType                         5803
# dropbackDistance                     5966
# passLocationType                     6812
# timeToThrow                          7419
# timeInTackleBox                      7207
# timeToSack                          15516
# passTippedAtLine                     6788
# unblockedPressure                    6369
# qbSpike                              6788
# qbKneel                                 0
# qbSneak                              9336
# rushLocationType                     9336
# penaltyYards                        15740
# prePenaltyYardsGained                   0
# yardsGained                             0
# homeTeamWinProbabilityAdded             0
# visitorTeamWinProbilityAdded            0
# expectedPointsAdded                     0
# isDropback                              0
# pff_runConceptPrimary                7053
# pff_runConceptSecondary             13303
# pff_runPassOption                       0
# pff_passCoverage                      192
# pff_manZone                           192
# dtype: int64
#
# Missing values in Players dataset:
#  nflId            0
# height           0
# weight           0
# birthDate      487
# collegeName      0
# position         0
# displayName      0
# dtype: int64
#
# Missing values in Tracking dataset:
#  gameId                 0
# playId                 0
# nflId             112709
# displayName            0
# frameId                0
# frameType              0
# time                   0
# jerseyNumber      112709
# club                   0
# playDirection          0
# x                      0
# y                      0
# s                      0
# a                      0
# dis                    0
# o                 112570
# dir               112570
# event            2481524
# dtype: int64

# %%
# Descriptive statistics
print("Plays dataset statistics:\n", plays.describe(), "\n")
print("Players dataset statistics:\n", players.describe(), "\n")
print("Tracking dataset statistics:\n", tracking.describe(), "\n")
# Out:
# Plays dataset statistics:
#               gameId        playId       quarter          down     yardsToGo  \
# count  1.612400e+04  16124.000000  16124.000000  16124.000000  16124.000000
# mean   2.022099e+09   2023.830563      2.572253      1.800794      8.461300
# std    5.979252e+03   1182.090771      1.135404      0.827194      3.908658
# min    2.022091e+09     54.000000      1.000000      1.000000      1.000000
# 25%    2.022093e+09    996.000000      2.000000      1.000000      6.000000
# 50%    2.022101e+09   2017.000000      3.000000      2.000000     10.000000
# 75%    2.022102e+09   3022.000000      4.000000      2.000000     10.000000
# max    2.022111e+09   5120.000000      5.000000      4.000000     38.000000
#
#        yardlineNumber  preSnapHomeScore  preSnapVisitorScore  \
# count    16124.000000      16124.000000         16124.000000
# mean        29.226185         11.255830            10.049615
# std         12.662828          9.468489             9.224680
# min          1.000000          0.000000             0.000000
# 25%         21.000000          3.000000             0.000000
# 50%         30.000000         10.000000             7.000000
# 75%         40.000000         17.000000            16.000000
# max         50.000000         49.000000            48.000000
#
#        absoluteYardlineNumber  preSnapHomeTeamWinProbability  ...  \
# count            16124.000000                   16124.000000  ...
# mean                60.413483                       0.552007  ...
# std                 24.326003                       0.290603  ...
# min                 11.000000                       0.001049  ...
# 25%                 40.000000                       0.324613  ...
# 50%                 61.000000                       0.578922  ...
# 75%                 81.000000                       0.791601  ...
# max                109.000000                       0.999197  ...
#
#        timeInTackleBox  timeToSack       qbKneel  penaltyYards  \
# count      8917.000000  608.000000  16124.000000    384.000000
# mean          2.632755    4.515796      0.010233      1.333333
# std           0.817805    1.314407      0.100643      8.785422
# min           0.000000    2.135000      0.000000    -20.000000
# 25%           2.079000    3.643750      0.000000      0.000000
# 50%           2.569000    4.249000      0.000000      0.000000
# 75%           3.100000    5.139000      0.000000      5.000000
# max           7.400000   11.912000      1.000000     15.000000
#
#        prePenaltyYardsGained   yardsGained  homeTeamWinProbabilityAdded  \
# count           16124.000000  16124.000000                 16124.000000
# mean                5.475254      5.460618                    -0.000065
# std                 8.622005      8.833095                     0.041561
# min               -18.000000    -68.000000                    -0.834887
# 25%                 0.000000      0.000000                    -0.012808
# 50%                 3.000000      3.000000                     0.000000
# 75%                 8.000000      8.000000                     0.013166
# max                98.000000     98.000000                     0.541161
#
#        visitorTeamWinProbilityAdded  expectedPointsAdded  pff_runPassOption
# count                  16124.000000         16124.000000       16124.000000
# mean                       0.000065            -0.029381           0.101340
# std                        0.041561             1.397405           0.301787
# min                       -0.541161           -13.023600           0.000000
# 25%                       -0.013166            -0.645440           0.000000
# 50%                        0.000000            -0.178783           0.000000
# 75%                        0.012808             0.696452           0.000000
# max                        0.834887             8.698986           1.000000
#
# [8 rows x 28 columns]
#
# Players dataset statistics:
#                nflId       weight
# count   1697.000000  1697.000000
# mean   48237.157336   245.774308
# std     5230.066814    47.256005
# min    25511.000000   153.000000
# 25%    44830.000000   205.000000
# 50%    47874.000000   236.000000
# 75%    53476.000000   291.000000
# max    55241.000000   380.000000
#
# Tracking dataset statistics:
#               gameId        playId         nflId       frameId  jerseyNumber  \
# count  2.593997e+06  2.593997e+06  2.481288e+06  2.593997e+06  2.481288e+06
# mean   2.022091e+09  1.857056e+03  4.708907e+04  8.680219e+01  4.847017e+01
# std    3.341400e+01  1.140260e+03  5.231637e+03  5.627552e+01  3.066499e+01
# min    2.022091e+09  5.500000e+01  2.551100e+04  1.000000e+00  1.000000e+00
# 25%    2.022091e+09  8.240000e+02  4.331600e+04  4.100000e+01  2.100000e+01
# 50%    2.022091e+09  1.815000e+03  4.650600e+04  8.100000e+01  5.200000e+01
# 75%    2.022091e+09  2.886000e+03  5.249700e+04  1.260000e+02  7.500000e+01
# max    2.022091e+09  4.137000e+03  5.515800e+04  4.250000e+02  9.900000e+01
#
#                   x             y             s             a           dis  \
# count  2.593997e+06  2.593997e+06  2.593997e+06  2.593997e+06  2.593997e+06
# mean   6.188549e+01  2.698751e+01  1.372835e+00  9.440309e-01  1.400948e-01
# std    2.505732e+01  7.739967e+00  1.898322e+00  1.189061e+00  1.954894e-01
# min   -5.060000e+00 -6.760000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.155000e+01  2.251000e+01  7.000000e-02  8.000000e-02  1.000000e-02
# 50%    6.220000e+01  2.698000e+01  5.700000e-01  5.300000e-01  6.000000e-02
# 75%    8.195000e+01  3.140000e+01  1.970000e+00  1.330000e+00  2.000000e-01
# max    1.256000e+02  6.947000e+01  2.771000e+01  4.243000e+01  6.800000e+00
#
#                   o           dir
# count  2.481427e+06  2.481427e+06
# mean   1.793379e+02  1.799429e+02
# std    9.748795e+01  1.047820e+02
# min    0.000000e+00  0.000000e+00
# 25%    8.908000e+01  8.894000e+01
# 50%    1.789500e+02  1.801700e+02
# 75%    2.693100e+02  2.707000e+02
# max    3.600000e+02  3.600000e+02

# %%
# Visualizations
plt.figure(figsize=(10, 6))
sns.countplot(data=plays, x='pff_runConceptPrimary')
plt.title('Distribution of Play Types')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(data=players, x='position')
plt.title('Distribution of Player Positions')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(tracking['s'], bins=30, kde=True)
plt.title('Distribution of Player Speeds')
plt.xlabel('Speed (yards/second)')
plt.show()
