# %%
import pandas as pd
import os
import random
import matplotlib.pyplot as plt
from src.formation_gui.field import Field

# %%
# Load datasets
data_files_basepath = f"{os.getcwd()}\\resources"

plays = pd.read_csv(f"{data_files_basepath}\\reduced_data.csv")

# %%
rand_game = random.choice(plays.gameId.unique())
rand_play = random.choice(plays[plays['gameId'] == rand_game].playId.unique())

play = plays[(plays['gameId'] == rand_game) & (plays['playId'] == rand_play)]
play
# Out:
#        Unnamed: 0      gameId  playId    nflId playDirection      x      y  \
# 80600      162940  2022092900     665  42654.0          left  71.90  33.10
# 80601      162943  2022092900     665  43344.0          left  72.09  18.82
# 80602      162944  2022092900     665  43510.0          left  71.18  29.78
# 80603      162945  2022092900     665  44860.0          left  76.13  27.58
# 80604      162947  2022092900     665  46094.0          left  72.78  34.97
# 80605      162949  2022092900     665  46163.0          left  71.54  31.49
# 80606      162950  2022092900     665  47794.0          left  71.97  26.84
# 80607      162953  2022092900     665  52409.0          left  75.69  29.95
# 80608      162954  2022092900     665  52441.0          left  71.80  43.49
# 80609      162957  2022092900     665  53434.0          left  71.44   9.72
# 80610      162959  2022092900     665  54601.0          left  71.79  28.28
#
#             o position offenseFormation
# 80600  268.92        T          SHOTGUN
# 80601  264.66       WR          SHOTGUN
# 80602  246.83        C          SHOTGUN
# 80603  275.32       RB          SHOTGUN
# 80604  270.50       TE          SHOTGUN
# 80605  270.58        G          SHOTGUN
# 80606  260.07        T          SHOTGUN
# 80607  274.35       QB          SHOTGUN
# 80608  256.37       WR          SHOTGUN
# 80609  275.49       WR          SHOTGUN
# 80610  272.03        G          SHOTGUN

# %%
from src.formation_gui.field import Field

field_viz = Field()

field_viz.generate_field()
field_viz.add_players(play)

# %%
if play.playDirection.unique()[0] == 'left':
    play = field_viz.flip_formation(play)

fig = field_viz.zoomed_formation(play)
