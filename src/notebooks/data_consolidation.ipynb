# %%
import pandas as pd
import random
import os

# %%
# Load datasets
data_files_basepath = f"{os.getcwd()}\\resources\\data"

plays = pd.read_csv(f"{data_files_basepath}\\plays.csv")
players = pd.read_csv(f"{data_files_basepath}\\players.csv")

# Combine all tracking weeks into a single DataFrame (first 2 weeks)
tracking_files = [f'tracking_week_{i}.csv' for i in range(1, 10)]
tracking_list = []
for file in tracking_files:
    try:
        print(f"Starting processing for {file}...")
        df = pd.read_csv(f"{data_files_basepath}\\{file}", on_bad_lines='skip', engine='python')
        tracking_list.append(df)
    except Exception as e:
        print(f"Error reading {file}: {e}")
tracking = pd.concat(tracking_list, ignore_index=True)

tracking = tracking.dropna()
# Out:
# Starting processing for tracking_week_1.csv...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 13
#      11 try:
#      12     print(f"Starting processing for {file}...")
# ---> 13     df = pd.read_csv(f"{data_files_basepath}\\{file}", on_bad_lines='skip', engine='python')
#      14     tracking_list.append(df)
#      15 except Exception as e:
#
# File c:\Development\AI 894 Capstone\redo\AA894-Group-4-Capstone\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Development\AI 894 Capstone\redo\AA894-Group-4-Capstone\.venv\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Development\AI 894 Capstone\redo\AA894-Group-4-Capstone\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Development\AI 894 Capstone\redo\AA894-Group-4-Capstone\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:252, in PythonParser.read(self, rows)
#     246 def read(
#     247     self, rows: int | None = None
#     248 ) -> tuple[
#     249     Index | None, Sequence[Hashable] | MultiIndex, Mapping[Hashable, ArrayLike]
#     250 ]:
#     251     try:
# --> 252         content = self._get_lines(rows)
#     253     except StopIteration:
#     254         if self._first_chunk:
#
# File c:\Development\AI 894 Capstone\redo\AA894-Group-4-Capstone\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:1140, in PythonParser._get_lines(self, rows)
#    1137 rows = 0
#    1139 while True:
# -> 1140     next_row = self._next_iter_line(row_num=self.pos + rows + 1)
#    1141     rows += 1
#    1143     if next_row is not None:
#
# File c:\Development\AI 894 Capstone\redo\AA894-Group-4-Capstone\.venv\Lib\site-packages\pandas\io\parsers\python_parser.py:805, in PythonParser._next_iter_line(self, row_num)
#     802 try:
#     803     # assert for mypy, data is Iterator[str] or None, would error in next
#     804     assert self.data is not None
# --> 805     line = next(self.data)
#     806     # for mypy
#     807     assert isinstance(line, list)
#
# File <frozen codecs>:319, in decode(self, input, final)
#
# KeyboardInterrupt:

# %%
players
# Out:
#       nflId height  weight   birthDate       collegeName position  \
# 0     25511    6-4     225  1977-08-03          Michigan       QB
# 1     29550    6-4     328  1982-01-22          Arkansas        T
# 2     29851    6-2     225  1983-12-02        California       QB
# 3     30842    6-6     267  1984-05-19              UCLA       TE
# 4     33084    6-4     217  1985-05-17    Boston College       QB
# ...     ...    ...     ...         ...               ...      ...
# 1692  55190    6-1     285         NaN          Maryland       DE
# 1693  55200    6-6     266         NaN           Indiana       DT
# 1694  55239    6-2     300         NaN      Pennsylvania       DT
# 1695  55240    6-1     185         NaN           Buffalo       CB
# 1696  55241    6-2     280         NaN  Coastal Carolina       DT
#
#            displayName
# 0            Tom Brady
# 1         Jason Peters
# 2        Aaron Rodgers
# 3       Marcedes Lewis
# 4            Matt Ryan
# ...                ...
# 1692    Sam Okuayinonu
# 1693    Ryder Anderson
# 1694      Prince Emili
# 1695  Ja'Marcus Ingram
# 1696       C.J. Brewer
#
# [1697 rows x 7 columns]

# %%
plays
# Out:
#            gameId  playId                                    playDescription  \
# 0      2022102302    2655  (1:54) (Shotgun) J.Burrow pass short middle to...
# 1      2022091809    3698  (2:13) (Shotgun) J.Burrow pass short right to ...
# 2      2022103004    3146  (2:00) (Shotgun) D.Mills pass short right to D...
# 3      2022110610     348  (9:28) (Shotgun) P.Mahomes pass short left to ...
# 4      2022102700    2799  (2:16) (Shotgun) L.Jackson up the middle to TB...
# ...           ...     ...                                                ...
# 16119  2022110604    1051  (12:49) (Shotgun) T.Lawrence pass incomplete s...
# 16120  2022103005    3492  (12:32) (Shotgun) K.Cousins pass incomplete de...
# 16121  2022092502    2337  (9:59) (Shotgun) P.Mahomes scrambles right end...
# 16122  2022091809     719  (:45) C.Rush pass incomplete deep right to C.L...
# 16123  2022101602    3046  (15:00) Br.Hall up the middle for 34 yards, TO...
#
#        quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0            3     1         10            CIN           ATL          CIN
# 1            4     1         10            CIN           DAL          CIN
# 2            4     3         12            HOU           TEN          HOU
# 3            1     2         10             KC           TEN          TEN
# 4            3     2          8            BAL            TB           TB
# ...        ...   ...        ...            ...           ...          ...
# 16119        2     3          4            JAX            LV          JAX
# 16120        4     1         10            MIN           ARI          MIN
# 16121        3     1         10             KC           IND          IND
# 16122        1     1         10            DAL           CIN          CIN
# 16123        4     1         10            NYJ            GB           GB
#
#        yardlineNumber  ... yardsGained  homeTeamWinProbabilityAdded  \
# 0                  21  ...           9                     0.004634
# 1                   8  ...           4                     0.002847
# 2                  20  ...           6                     0.000205
# 3                  23  ...           4                    -0.001308
# 4                  27  ...          -1                     0.027141
# ...               ...  ...         ...                          ...
# 16119              31  ...           0                    -0.024741
# 16120              25  ...           0                    -0.026580
# 16121              13  ...          10                    -0.013790
# 16122              47  ...           0                    -0.011561
# 16123              34  ...          34                    -0.051177
#
#        visitorTeamWinProbilityAdded expectedPointsAdded  isDropback  \
# 0                         -0.004634            0.702717        True
# 1                         -0.002847           -0.240509        True
# 2                         -0.000205           -0.218480        True
# 3                          0.001308           -0.427749        True
# 4                         -0.027141           -0.638912       False
# ...                             ...                 ...         ...
# 16119                      0.024741           -1.391687        True
# 16120                      0.026580           -0.503208        True
# 16121                      0.013790            1.073898        True
# 16122                      0.011561           -0.522397        True
# 16123                      0.051177            3.155436       False
#
#        pff_runConceptPrimary  pff_runConceptSecondary  pff_runPassOption  \
# 0                        NaN                      NaN                  0
# 1                        NaN                      NaN                  0
# 2                        NaN                      NaN                  0
# 3                        NaN                      NaN                  0
# 4                        MAN              READ OPTION                  0
# ...                      ...                      ...                ...
# 16119                    NaN                      NaN                  0
# 16120                    NaN                      NaN                  0
# 16121                    NaN                      NaN                  0
# 16122              UNDEFINED                      NaN                  0
# 16123                COUNTER             MISDIRECTION                  0
#
#       pff_passCoverage pff_manZone
# 0              Cover-3        Zone
# 1             Quarters        Zone
# 2             Quarters        Zone
# 3             Quarters        Zone
# 4              Cover-1         Man
# ...                ...         ...
# 16119          Cover-2        Zone
# 16120          Cover-3        Zone
# 16121         Quarters        Zone
# 16122          Cover-3        Zone
# 16123          Cover-3        Zone
#
# [16124 rows x 50 columns]

# %%
tracking
# Out:
#               gameId  playId    nflId       displayName  frameId    frameType  \
# 0         2022091200      64  35459.0    Kareem Jackson        1  BEFORE_SNAP
# 42        2022091200      64  35459.0    Kareem Jackson       43  BEFORE_SNAP
# 64        2022091200      64  35459.0    Kareem Jackson       65  BEFORE_SNAP
# 113       2022091200      64  35459.0    Kareem Jackson      114         SNAP
# 126       2022091200      64  35459.0    Kareem Jackson      127   AFTER_SNAP
# ...              ...     ...      ...               ...      ...          ...
# 59327275  2022110300    3579  54540.0  Christian Harris       26         SNAP
# 59327286  2022110300    3579  54540.0  Christian Harris       37   AFTER_SNAP
# 59327296  2022110300    3579  54663.0  Grant Calcaterra        6  BEFORE_SNAP
# 59327316  2022110300    3579  54663.0  Grant Calcaterra       26         SNAP
# 59327327  2022110300    3579  54663.0  Grant Calcaterra       37   AFTER_SNAP
#
#                            time  jerseyNumber club playDirection      x  \
# 0         2022-09-13 00:16:03.5          22.0  DEN         right  51.06
# 42        2022-09-13 00:16:07.7          22.0  DEN         right  51.88
# 64        2022-09-13 00:16:09.9          22.0  DEN         right  50.70
# 113       2022-09-13 00:16:14.8          22.0  DEN         right  50.29
# 126       2022-09-13 00:16:16.1          22.0  DEN         right  53.10
# ...                         ...           ...  ...           ...    ...
# 59327275  2022-11-04 03:04:34.4          48.0  HOU          left  73.05
# 59327286  2022-11-04 03:04:35.5          48.0  HOU          left  73.42
# 59327296  2022-11-04 03:04:32.4          81.0  PHI          left  76.22
# 59327316  2022-11-04 03:04:34.4          81.0  PHI          left  76.17
# 59327327  2022-11-04 03:04:35.5          81.0  PHI          left  76.17
#
#               y     s     a   dis       o     dir                 event
# 0         28.55  0.72  0.37  0.07  246.17   68.34  huddle_break_offense
# 42        29.07  0.34  0.26  0.03  261.81  303.38              line_set
# 64        29.39  0.68  0.36  0.07  262.63  297.92         man_in_motion
# 113       29.43  1.13  1.62  0.11  240.06  133.16             ball_snap
# 126       26.61  4.66  2.37  0.46  204.08  147.79               handoff
# ...         ...   ...   ...   ...     ...     ...                   ...
# 59327275  30.43  0.51  0.34  0.05   85.39  103.76             ball_snap
# 59327286  30.42  0.28  0.22  0.03   71.72   45.92              qb_kneel
# 59327296  33.76  0.00  0.05  0.00  227.71  129.08              line_set
# 59327316  33.76  0.01  0.01  0.01  240.77  251.49             ball_snap
# 59327327  33.65  0.01  0.01  0.01  250.15  192.44              qb_kneel
#
# [2435796 rows x 18 columns]

# %%
print(tracking.shape)

snap_data = tracking[tracking['event'] == 'ball_snap']

players_positions = players[['nflId', 'displayName','position']]
possession_tracker = plays[['gameId', "playId", "possessionTeam", "defensiveTeam", "offenseFormation"]]

play_data = pd.merge(snap_data, plays, on=['gameId', 'playId'])
full_data = pd.merge(play_data, players, on=['nflId', 'displayName'])
clean_data = full_data.drop_duplicates()

clean_data
# Out:
# (2435796, 18)
#             gameId  playId    nflId       displayName  frameId frameType  \
# 0       2022091200      64  35459.0    Kareem Jackson      114      SNAP
# 1       2022091200      64  39987.0        Geno Smith      114      SNAP
# 2       2022091200      64  41310.0      Gabe Jackson      114      SNAP
# 3       2022091200      64  42393.0      Ronald Darby      114      SNAP
# 4       2022091200      64  42403.0     Randy Gregory      114      SNAP
# ...            ...     ...      ...               ...      ...       ...
# 351750  2022110300    3579  53946.0        Jack Stoll       26      SNAP
# 351751  2022110300    3579  54468.0    Derek Stingley       26      SNAP
# 351752  2022110300    3579  54502.0       Jalen Pitre       26      SNAP
# 351753  2022110300    3579  54540.0  Christian Harris       26      SNAP
# 351754  2022110300    3579  54663.0  Grant Calcaterra       26      SNAP
#
#                          time  jerseyNumber club playDirection  ...  \
# 0       2022-09-13 00:16:14.8          22.0  DEN         right  ...
# 1       2022-09-13 00:16:14.8           7.0  SEA         right  ...
# 2       2022-09-13 00:16:14.8          66.0  SEA         right  ...
# 3       2022-09-13 00:16:14.8          23.0  DEN         right  ...
# 4       2022-09-13 00:16:14.8           5.0  DEN         right  ...
# ...                       ...           ...  ...           ...  ...
# 351750  2022-11-04 03:04:34.4          89.0  PHI          left  ...
# 351751  2022-11-04 03:04:34.4          24.0  HOU          left  ...
# 351752  2022-11-04 03:04:34.4           5.0  HOU          left  ...
# 351753  2022-11-04 03:04:34.4          48.0  HOU          left  ...
# 351754  2022-11-04 03:04:34.4          81.0  PHI          left  ...
#
#         pff_runConceptPrimary  pff_runConceptSecondary  pff_runPassOption  \
# 0                OUTSIDE ZONE               LEAD;PITCH                  0
# 1                OUTSIDE ZONE               LEAD;PITCH                  0
# 2                OUTSIDE ZONE               LEAD;PITCH                  0
# 3                OUTSIDE ZONE               LEAD;PITCH                  0
# 4                OUTSIDE ZONE               LEAD;PITCH                  0
# ...                       ...                      ...                ...
# 351750              UNDEFINED                      NaN                  0
# 351751              UNDEFINED                      NaN                  0
# 351752              UNDEFINED                      NaN                  0
# 351753              UNDEFINED                      NaN                  0
# 351754              UNDEFINED                      NaN                  0
#
#         pff_passCoverage  pff_manZone  height  weight   birthDate  \
# 0                Cover-3         Zone    5-10     185  1988-04-10
# 1                Cover-3         Zone     6-3     221  1990-10-10
# 2                Cover-3         Zone     6-3     336  1991-07-12
# 3                Cover-3         Zone    5-11     193  1994-01-02
# 4                Cover-3         Zone     6-5     255  1992-11-23
# ...                  ...          ...     ...     ...         ...
# 351750               NaN          NaN     6-4     260         NaN
# 351751               NaN          NaN     6-1     195         NaN
# 351752               NaN          NaN     6-0     200         NaN
# 351753               NaN          NaN     6-2     232         NaN
# 351754               NaN          NaN     6-4     221         NaN
#
#                collegeName  position
# 0                  Alabama        SS
# 1            West Virginia        QB
# 2        Mississippi State         G
# 3            Florida State        CB
# 4                 Nebraska       OLB
# ...                    ...       ...
# 351750            Nebraska        TE
# 351751     Louisiana State        CB
# 351752              Baylor        FS
# 351753             Alabama       ILB
# 351754  Southern Methodist        TE
#
# [351755 rows x 71 columns]

# %%
offensive_data = clean_data[clean_data['club'] == clean_data['possessionTeam']][clean_data['position'].isin(['C', 'G', 'T', 'TE', 'WR', 'RB', 'FB', 'QB'])]
offensive_data['uniquePlayId'] = clean_data['gameId'].astype(str) + '-' + clean_data['playId'].astype(str)

offensive_data
# Out:
# C:\Users\zieli\AppData\Local\Temp\ipykernel_2800\934262058.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   offensive_data = clean_data[clean_data['club'] == clean_data['possessionTeam']][clean_data['position'].isin(['C', 'G', 'T', 'TE', 'WR', 'RB', 'FB', 'QB'])]
#             gameId  playId    nflId       displayName  frameId frameType  \
# 1       2022091200      64  39987.0        Geno Smith      114      SNAP
# 2       2022091200      64  41310.0      Gabe Jackson      114      SNAP
# 5       2022091200      64  42412.0     Tyler Lockett      114      SNAP
# 9       2022091200      64  43537.0     Austin Blythe      114      SNAP
# 12      2022091200      64  46096.0     Rashaad Penny      114      SNAP
# ...            ...     ...      ...               ...      ...       ...
# 351745  2022110300    3579  52461.0       Jalen Hurts       26      SNAP
# 351746  2022110300    3579  53466.0  Landon Dickerson       26      SNAP
# 351747  2022110300    3579  53579.0  Kenneth Gainwell       26      SNAP
# 351750  2022110300    3579  53946.0        Jack Stoll       26      SNAP
# 351754  2022110300    3579  54663.0  Grant Calcaterra       26      SNAP
#
#                          time  jerseyNumber club playDirection  ...  \
# 1       2022-09-13 00:16:14.8           7.0  SEA         right  ...
# 2       2022-09-13 00:16:14.8          66.0  SEA         right  ...
# 5       2022-09-13 00:16:14.8          16.0  SEA         right  ...
# 9       2022-09-13 00:16:14.8          63.0  SEA         right  ...
# 12      2022-09-13 00:16:14.8          20.0  SEA         right  ...
# ...                       ...           ...  ...           ...  ...
# 351745  2022-11-04 03:04:34.4           1.0  PHI          left  ...
# 351746  2022-11-04 03:04:34.4          69.0  PHI          left  ...
# 351747  2022-11-04 03:04:34.4          14.0  PHI          left  ...
# 351750  2022-11-04 03:04:34.4          89.0  PHI          left  ...
# 351754  2022-11-04 03:04:34.4          81.0  PHI          left  ...
#
#         pff_runConceptSecondary  pff_runPassOption  pff_passCoverage  \
# 1                    LEAD;PITCH                  0           Cover-3
# 2                    LEAD;PITCH                  0           Cover-3
# 5                    LEAD;PITCH                  0           Cover-3
# 9                    LEAD;PITCH                  0           Cover-3
# 12                   LEAD;PITCH                  0           Cover-3
# ...                         ...                ...               ...
# 351745                      NaN                  0               NaN
# 351746                      NaN                  0               NaN
# 351747                      NaN                  0               NaN
# 351750                      NaN                  0               NaN
# 351754                      NaN                  0               NaN
#
#         pff_manZone  height  weight   birthDate         collegeName position  \
# 1              Zone     6-3     221  1990-10-10       West Virginia       QB
# 2              Zone     6-3     336  1991-07-12   Mississippi State        G
# 5              Zone    5-10     182  1992-09-28        Kansas State       WR
# 9              Zone     6-3     300  1992-06-16                Iowa        C
# 12             Zone    5-11     220  1996-02-02     San Diego State       RB
# ...             ...     ...     ...         ...                 ...      ...
# 351745          NaN     6-2     218  1998-08-07            Oklahoma       QB
# 351746          NaN     6-6     325         NaN             Alabama        G
# 351747          NaN    5-11     191         NaN             Memphis       RB
# 351750          NaN     6-4     260         NaN            Nebraska       TE
# 351754          NaN     6-4     221         NaN  Southern Methodist       TE
#
#            uniquePlayId
# 1         2022091200-64
# 2         2022091200-64
# 5         2022091200-64
# 9         2022091200-64
# 12        2022091200-64
# ...                 ...
# 351745  2022110300-3579
# 351746  2022110300-3579
# 351747  2022110300-3579
# 351750  2022110300-3579
# 351754  2022110300-3579
#
# [176084 rows x 72 columns]

# %%
print(f"Available Formations: {offensive_data.offenseFormation.unique()}")
print(f"Available Positions: {offensive_data.position.unique()}")
print(f"Total Games: {len(offensive_data.gameId.unique())}")
print(f"Total Plays: {len(offensive_data)//11}")
print(f"Total Players: {len(offensive_data.nflId.unique())}")

reduced_data = offensive_data[['uniquePlayId', 'nflId', 'playDirection', 'x', 'y', 'o', 'position', 'offenseFormation']]
# Out:
# Available Formations: ['SINGLEBACK' 'EMPTY' 'SHOTGUN' 'PISTOL' 'I_FORM' 'JUMBO' 'WILDCAT']
# Available Positions: ['QB' 'G' 'WR' 'C' 'RB' 'TE' 'T' 'FB']
# Total Games: 136
# Total Plays: 15820
# Total Players: 823

# %%
reduced_data
# Out:
#            uniquePlayId    nflId playDirection      x      y       o position  \
# 1         2022091200-64  39987.0         right  37.94  23.86   79.67       QB
# 2         2022091200-64  41310.0         right  38.52  22.21  134.48        G
# 5         2022091200-64  42412.0         right  39.41  14.39   82.82       WR
# 9         2022091200-64  43537.0         right  39.17  23.66   74.04        C
# 12        2022091200-64  46096.0         right  32.15  23.82   96.33       RB
# ...                 ...      ...           ...    ...    ...     ...      ...
# 351723  2022110300-3538  52608.0          left  76.93  43.23  262.21       WR
# 351724  2022110300-3538  53466.0          left  76.41  28.73  279.34        G
# 351725  2022110300-3538  53579.0          left  82.59  29.75  270.00       RB
# 351728  2022110300-3538  53946.0          left  76.88  26.10  299.90       TE
# 351732  2022110300-3538  54663.0          left  77.82  33.01  235.00       TE
#
#        offenseFormation
# 1            SINGLEBACK
# 2            SINGLEBACK
# 5            SINGLEBACK
# 9            SINGLEBACK
# 12           SINGLEBACK
# ...                 ...
# 351723           I_FORM
# 351724           I_FORM
# 351725           I_FORM
# 351728           I_FORM
# 351732           I_FORM
#
# [174029 rows x 8 columns]

# %%
reduced_data.to_csv("resources\\reduced_data.csv")
